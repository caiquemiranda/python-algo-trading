# %%
import MetaTrader5 as mt5
import pandas as pd
import pandas_ta as ta
import time
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import pytz
from pylab import mpl, plt

# %%
if not mt5.initialize():
    print('initialize() falhou')
    mt5.shutdown()

# %%
plt.style.use('seaborn')
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'

# %%
ativo_analise = 'WDOH22'
df_analise = mt5.copy_ticks_from(ativo_analise, datetime(2022, 1, 2),100000000, mt5.COPY_TICKS_ALL)
df_analise = pd.DataFrame(df_analise)
df_analise['time'] = pd.to_datetime(df_analise['time'], unit='s')
df_analise.drop(['flags', 'time_msc', 'volume_real'], axis = 1, inplace=True)
df_analise.set_index('time', inplace=True)
df_analise['IFR5'] = ta.rsi(df_analise['last'], length=5)
df_analise['IFR9'] = ta.rsi(df_analise['last'], length=9)
df_analise['IFR14'] = ta.rsi(df_analise['last'], length=14)
df_analise
# Out:
#                         bid     ask    last  volume       IFR5       IFR9  \
# time
# 2022-01-03 09:03:00     0.0  5728.0     0.0       0        NaN        NaN
# 2022-01-03 09:03:59  5673.0  5728.0     0.0       0        NaN        NaN
# 2022-01-03 09:04:06     0.0  5728.0     0.0       0        NaN        NaN
# 2022-01-03 09:04:29     0.0  5700.0     0.0       0        NaN        NaN
# 2022-01-03 09:04:56     0.0  5675.0     0.0       0        NaN        NaN
# ...                     ...     ...     ...     ...        ...        ...
# 2022-02-04 18:29:59  5359.5  5360.0  5361.0       1  79.626547  69.887415
# 2022-02-04 18:29:59  5359.0  5361.0  5361.0       1  79.626547  69.887415
# 2022-02-04 18:29:59  5359.0  5361.0  5359.0       4  26.246273  37.913130
# 2022-02-04 19:30:00     0.0     0.0  5359.0       4  26.246273  37.913130
# 2022-02-04 21:00:10     0.0     0.0  5359.0       4  26.246273  37.913130
#
#                          IFR14
# time
# 2022-01-03 09:03:00        NaN
# 2022-01-03 09:03:59        NaN
# 2022-01-03 09:04:06        NaN
# 2022-01-03 09:04:29        NaN
# 2022-01-03 09:04:56        NaN
# ...                        ...
# 2022-02-04 18:29:59  64.633682
# 2022-02-04 18:29:59  64.633682
# 2022-02-04 18:29:59  43.357646
# 2022-02-04 19:30:00  43.357646
# 2022-02-04 21:00:10  43.357646
#
# [1342743 rows x 7 columns]

# %%
df = df_analise.loc['2022-02-04 09:30:00' : '2022-02-04 16:30:00']
df
# Out:
#                         bid     ask    last  volume       IFR5       IFR9  \
# time
# 2022-02-04 09:30:00  5319.5  5320.0  5319.5       5  42.029322  43.331389
# 2022-02-04 09:30:00  5319.5  5320.0  5320.0       5  61.064384  54.321620
# 2022-02-04 09:30:00  5319.5  5320.0  5320.0       1  61.064384  54.321620
# 2022-02-04 09:30:00  5319.5  5320.0  5319.5       8  40.358274  43.615935
# 2022-02-04 09:30:00  5319.5  5320.0  5320.0       1  58.112593  53.848415
# ...                     ...     ...     ...     ...        ...        ...
# 2022-02-04 16:30:00  5357.0  5357.5  5357.5       1  55.643948  53.688883
# 2022-02-04 16:30:00  5357.0  5357.5  5357.5       2  55.643948  53.688883
# 2022-02-04 16:30:00  5357.0  5357.5  5357.0      17  36.922310  41.955690
# 2022-02-04 16:30:00  5357.0  5357.5  5357.0       2  36.922310  41.955690
# 2022-02-04 16:30:00  5357.0  5357.5  5357.5       1  58.656819  54.531762
#
#                          IFR14
# time
# 2022-02-04 09:30:00  44.450453
# 2022-02-04 09:30:00  51.590503
# 2022-02-04 09:30:00  51.590503
# 2022-02-04 09:30:00  44.897618
# 2022-02-04 09:30:00  51.652289
# ...                        ...
# 2022-02-04 16:30:00  53.441146
# 2022-02-04 16:30:00  53.441146
# 2022-02-04 16:30:00  45.017362
# 2022-02-04 16:30:00  45.017362
# 2022-02-04 16:30:00  53.515256
#
# [193872 rows x 7 columns]

# %%
df = df[1000:11000]
df
# Out:
#                         bid     ask    last  volume       IFR5       IFR9  \
# time
# 2022-02-04 09:31:44  5324.5  5325.0  5324.5      10  38.574291  44.484173
# 2022-02-04 09:31:44  5324.5  5325.0  5325.0       1  56.295744  53.684404
# 2022-02-04 09:31:44  5324.5  5325.0  5324.5       5  41.374831  45.248386
# 2022-02-04 09:31:44  5324.5  5325.0  5325.0       1  55.964181  53.473506
# 2022-02-04 09:31:44  5324.5  5325.0  5325.0       3  55.964181  53.473506
# ...                     ...     ...     ...     ...        ...        ...
# 2022-02-04 09:48:52  5322.5  5323.0  5322.5       2  43.398366  44.500806
# 2022-02-04 09:48:52  5322.5  5323.0  5322.5      49  43.398366  44.500806
# 2022-02-04 09:48:52  5322.5  5323.0  5322.5     176  43.398366  44.500806
# 2022-02-04 09:48:52  5322.5  5323.0  5323.0      50  62.985474  54.827115
# 2022-02-04 09:48:52  5322.5  5323.0  5322.5       1  43.966923  45.337140
#
#                          IFR14
# time
# 2022-02-04 09:31:44  46.861740
# 2022-02-04 09:31:44  52.514116
# 2022-02-04 09:31:44  47.116729
# 2022-02-04 09:31:44  52.386834
# 2022-02-04 09:31:44  52.386834
# ...                        ...
# 2022-02-04 09:48:52  44.834007
# 2022-02-04 09:48:52  44.834007
# 2022-02-04 09:48:52  44.834007
# 2022-02-04 09:48:52  51.320152
# 2022-02-04 09:48:52  45.552346
#
# [10000 rows x 7 columns]

# %%
def percentil(data, up=90, down=10):
    x = data
    array_x = np.array(x)
    percentil_up = np.percentile(array_x, up)
    percentil_down = np.percentile(array_x, down)
    return percentil_up, percentil_down

# %%
plt.rcParams['figure.figsize'] = (20,4)

per_ifr5 = percentil(df['IFR5'], up=99, down=1)
ax = df['IFR5'].plot()
ax.fill_between(df.index, 90, 10,facecolor= 'orange', alpha= 0.1)
plt.axhline(per_ifr5[0], color="red")
plt.axhline(90.0, color="grey")
plt.axhline(10.0, color="grey")
plt.axhline(per_ifr5[1], color="green")
plt.xlabel('Time')
plt.ylabel('IFR5')
plt.show()

per_ifr9 = percentil(df['IFR9'], up=99, down=1)
ax = df['IFR9'].plot()
ax.fill_between(df.index, 90, 10,facecolor= 'orange', alpha= 0.1)
plt.axhline(per_ifr9[0], color="red")
plt.axhline(90.0, color="grey")
plt.axhline(10.0, color="grey")
plt.axhline(per_ifr9[1], color="green")
plt.xlabel('Time')
plt.ylabel('IFR9')
plt.show()

per_ifr14 = percentil(df['IFR14'], up=99, down=1)
ax = df['IFR14'].plot()
ax.fill_between(df.index, 90, 10,facecolor= 'orange', alpha= 0.1)
plt.axhline(per_ifr14[0], color="red")
plt.axhline(90.0, color="grey")
plt.axhline(10.0, color="grey")
plt.axhline(per_ifr14[1], color="green")
plt.xlabel('Time')
plt.ylabel('IFR14')
plt.show()

# %%
df['IFR5'].describe()
# Out:
# count    10000.000000
# mean        49.904419
# std         11.268368
# min          3.191445
# 25%         40.991156
# 50%         49.521132
# 75%         58.746355
# max         92.852568
# Name: IFR5, dtype: float64

# %%
ifr = df.loc[df['IFR9'] >= 98.0]
ifr2 = ifr.loc[ifr['volume'] >= 0]
ifr2['spread'] = ifr2['ask']-ifr2['last']
ifr2.head(30)
# Out:
# Empty DataFrame
# Columns: [bid, ask, last, volume, IFR5, IFR9, IFR14, spread]
# Index: []

# %%
df['IFR9'].describe()
# Out:
# count    10000.000000
# mean        49.932145
# std          6.521884
# min         17.533454
# 25%         45.052302
# 50%         50.010422
# 75%         54.771269
# max         81.119029
# Name: IFR9, dtype: float64

# %%
df['IFR14'].describe()
# Out:
# count    10000.000000
# mean        49.949802
# std          4.488330
# min         30.191584
# 25%         46.786704
# 50%         50.000102
# 75%         53.088480
# max         72.459058
# Name: IFR14, dtype: float64
